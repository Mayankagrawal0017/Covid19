# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Corona_dataset = pd.read_csv("data/covid19/c19/time_series_covid_19_confirmed.csv")

# %%
cd=Corona_dataset
cd.shape
# Out:
# (266, 185)

# %%
cd.head(50)
# Out:
#                   Province/State            Country/Region        Lat  \
# 0                            NaN               Afghanistan  33.939110
# 1                            NaN                   Albania  41.153300
# 2                            NaN                   Algeria  28.033900
# 3                            NaN                   Andorra  42.506300
# 4                            NaN                    Angola -11.202700
# 5                            NaN       Antigua and Barbuda  17.060800
# 6                            NaN                 Argentina -38.416100
# 7                            NaN                   Armenia  40.069100
# 8   Australian Capital Territory                 Australia -35.473500
# 9                New South Wales                 Australia -33.868800
# 10            Northern Territory                 Australia -12.463400
# 11                    Queensland                 Australia -27.469800
# ...

# %% [markdown]
# Deleat Long,lat Column's

# %%
cd.drop(["Lat","Long"],axis=1,inplace=True)
cd.head(50)
# Out:
#                   Province/State            Country/Region  1/22/20  1/23/20  \
# 0                            NaN               Afghanistan        0        0
# 1                            NaN                   Albania        0        0
# 2                            NaN                   Algeria        0        0
# 3                            NaN                   Andorra        0        0
# 4                            NaN                    Angola        0        0
# 5                            NaN       Antigua and Barbuda        0        0
# 6                            NaN                 Argentina        0        0
# 7                            NaN                   Armenia        0        0
# 8   Australian Capital Territory                 Australia        0        0
# 9                New South Wales                 Australia        0        0
# 10            Northern Territory                 Australia        0        0
# ...

# %% [markdown]
# Group data according to Country/Region

# %%
cd=cd.groupby("Country/Region").sum()

# %%
cd
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %%
cd.loc["China"].plot()
cd.loc["Spain"].plot()
cd.loc["Italy"].plot()
plt.legend()

# %%
cd.loc["China"][:3].plot()

# %%
cd.loc["China"].diff().plot()

# %%
cd.loc["China"].diff().max()
# Out:
# 15136.0

# %%
Max_rate=[]
for i in range(0,188):
    x=cd.loc[cd.index[i]].diff().max()
    Max_rate.append(x)
len(Max_rate)
# Out:
# 188

# %%
Country=cd.index
Country
# Out:
# Index(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Antigua and Barbuda', 'Argentina', 'Armenia', 'Australia', 'Austria',
#        ...
#        'United Kingdom', 'Uruguay', 'Uzbekistan', 'Venezuela', 'Vietnam',
#        'West Bank and Gaza', 'Western Sahara', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country/Region', length=188)

# %%
sss =pd.DataFrame()
sss["mri"]=Max_rate
sss["Country"]=Country

# %%
sss.set_index("Country")
# Out:
#                       mri
# Country
# Afghanistan         915.0
# Albania             117.0
# Algeria             607.0
# Andorra              79.0
# Angola               62.0
# ...                   ...
# West Bank and Gaza  501.0
# Western Sahara        4.0
# Yemen               116.0
# Zambia              915.0
# Zimbabwe            273.0
#
# [188 rows x 1 columns]

# %%
cd
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %%
corona_data=pd.DataFrame(sss["mri"])

# %%
corona_data
# Out:
#                       mri
# Country/Region
# Afghanistan         915.0
# Albania             117.0
# Algeria             607.0
# Andorra              79.0
# Angola               62.0
# ...                   ...
# West Bank and Gaza  501.0
# Western Sahara        4.0
# Yemen               116.0
# Zambia              915.0
# Zimbabwe            273.0
#
# [188 rows x 1 columns]

# %%
corona_data.to_csv("data/COVID19/C19/CDMRI.csv")

# %% [markdown]
# find sum of all dates of world data diff.

# %%
type(cd["1/22/20"])
# Out:
# pandas.core.series.Series

# %%
cd["1/22/20"].sum(axis=0)
# Out:
# 555

# %%
dcd=pd.DataFrame(columns=list(cd.columns))

# %%
dcd
# Out:
# Empty DataFrame
# Columns: [1/22/20, 1/23/20, 1/24/20, 1/25/20, 1/26/20, 1/27/20, 1/28/20, 1/29/20, 1/30/20, 1/31/20, 2/1/20, 2/2/20, 2/3/20, 2/4/20, 2/5/20, 2/6/20, 2/7/20, 2/8/20, 2/9/20, 2/10/20, 2/11/20, 2/12/20, 2/13/20, 2/14/20, 2/15/20, 2/16/20, 2/17/20, 2/18/20, 2/19/20, 2/20/20, 2/21/20, 2/22/20, 2/23/20, 2/24/20, 2/25/20, 2/26/20, 2/27/20, 2/28/20, 2/29/20, 3/1/20, 3/2/20, 3/3/20, 3/4/20, 3/5/20, 3/6/20, 3/7/20, 3/8/20, 3/9/20, 3/10/20, 3/11/20, 3/12/20, 3/13/20, 3/14/20, 3/15/20, 3/16/20, 3/17/20, 3/18/20, 3/19/20, 3/20/20, 3/21/20, 3/22/20, 3/23/20, 3/24/20, 3/25/20, 3/26/20, 3/27/20, 3/28/20, 3/29/20, 3/30/20, 3/31/20, 4/1/20, 4/2/20, 4/3/20, 4/4/20, 4/5/20, 4/6/20, 4/7/20, 4/8/20, 4/9/20, 4/10/20, 4/11/20, 4/12/20, 4/13/20, 4/14/20, 4/15/20, 4/16/20, 4/17/20, 4/18/20, 4/19/20, 4/20/20, 4/21/20, 4/22/20, 4/23/20, 4/24/20, 4/25/20, 4/26/20, 4/27/20, 4/28/20, 4/29/20, 4/30/20, ...]
# Index: []
#
# [0 rows x 181 columns]

# %%
dcd["Country/Region"] = list(cd.index)

# %%
dcd
# Out:
#     1/22/20 1/23/20 1/24/20 1/25/20 1/26/20 1/27/20 1/28/20 1/29/20 1/30/20  \
# 0       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4       NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 183     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 184     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 185     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 186     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 187     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
for x in range(0,len(cd.columns)+1):
    L=list(cd.loc[cd.index[x]].diff())
    for y in range(0,len(cd.columns)):
        dcd.loc[x,dcd.columns[y]]=L[y]

# %%
dcd.set_index("Country/Region" ,inplace=True)

# %%
x=input("enter country name")
x=x.capitalize()
z= dcd.loc[x]
plt.figure(figsize=(10,8))
z.plot()
# Out:
# enter country nameindia

# %%
WD=cd.sum(axis=0)
WD
# Out:
# 1/22/20         555
# 1/23/20         654
# 1/24/20         941
# 1/25/20        1434
# 1/26/20        2118
#              ...
# 7/16/20    13813333
# 7/17/20    14055299
# 7/18/20    14292922
# 7/19/20    14507491
# 7/20/20    14703293
# Length: 181, dtype: int64

# %%
WD.diff().plot()

# %%
WD.diff().max()

# %%
Wdiff=WD.diff()
Wdiff

# %%
World=list(cd.sum(axis=0))

# %%
LL=list(cd.columns)

# %%
Wcd =  pd.DataFrame(columns=LL)

# %%
Wcd.columns
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20',
#        ...
#        '7/11/20', '7/12/20', '7/13/20', '7/14/20', '7/15/20', '7/16/20',
#        '7/17/20', '7/18/20', '7/19/20', '7/20/20'],
#       dtype='object', length=181)

# %%
 Wcd.columns[3]
# Out:
# '1/25/20'

# %%
len(Wcd.columns)
# Out:
# 181

# %%
for i in range(0,len(Wcd.columns)):
        Wcd.loc[1,Wcd.columns[i]]=World[i]

# %%
for i in range(0,len(Wcd.columns)):      
    Wcd.loc[2,Wcd.columns[i]]=Wdiff[i]

# %%
Wcd["Row"]=["World_confirmed_cases","New_cases"]
Wcd=Wcd.set_index("Row")

# %%
Wcd
# Out:
#                       1/22/20 1/23/20 1/24/20 1/25/20 1/26/20 1/27/20 1/28/20  \
# Row
# World_confirmed_cases     555     654     941    1434    2118    2927    5578
# New_cases                 NaN      99     287     493     684     809    2651
#
#                       1/29/20 1/30/20 1/31/20  ...      7/12/20      7/13/20  \
# Row                                            ...
# World_confirmed_cases    6166    8234    9927  ...  1.29154e+07  1.31082e+07
# New_cases                 588    2068    1693  ...       192676       192783
#
#                            7/14/20      7/15/20      7/16/20      7/17/20  \
# Row
# World_confirmed_cases  1.33297e+07  1.35608e+07  1.38133e+07  1.40553e+07
# New_cases                   221455       231125       252530       241966
#
#                            7/18/20      7/19/20      7/20/20          mri
# Row
# World_confirmed_cases  1.42929e+07  1.45075e+07  1.47033e+07       489151
# ...

# %%
dcd.to_csv("data/COVID19/C19/new_cases_time_line.csv")

# %%
Wcd.to_csv("data/COVID19/C19/World_cases_time_line.csv")
